# %%
# Importing necessary libraries
import matplotlib.pyplot as plt  # For plotting
import numpy as np  # For numerical operations
import tensorflow as tf  # For machine learning and deep learning functionalities
from tensorflow.keras.preprocessing import image_dataset_from_directory  # For creating a dataset from a directory of images
from tensorflow.keras.callbacks import Callback, EarlyStopping  # For model training callbacks
import pathlib  # For working with file paths
from imgaug import augmenters as iaa  # For image augmentation techniques
from google.colab import drive  # For Google Colab-specific functionalities

# %%
# Installing and importing PyDrive and other necessary libraries
# !pip install -U -q PyDrive  # Upgrading or installing PyDrive library
from pydrive.auth import GoogleAuth  # Importing GoogleAuth for Google Drive authentication
from pydrive.drive import GoogleDrive  # Importing GoogleDrive for Google Drive file manipulation
from google.colab import auth  # Importing auth for Google Colab authentication
from oauth2client.client import GoogleCredentials  # Importing GoogleCredentials for OAuth2 authentication
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
auth.authenticate_user()  # Authenticating the user
gauth = GoogleAuth()  # Initializing GoogleAuth object
gauth.credentials = GoogleCredentials.get_application_default()  # Setting credentials using GoogleCredentials
drive = GoogleDrive(gauth)  # Creating a GoogleDrive object using the authenticated credentials

# %%
downloaded = drive.CreateFile({'id':'1p_xGicUMvt3tKo340jLnjK2wV9sc1sJG'})
downloaded.GetContentFile('Rempah.zip')  # Downloading a file with the specified ID and saving it as 'Rempah.zip'

# %%
from zipfile import ZipFile

with ZipFile('Rempah.zip', 'r') as zipObj:
    zipObj.extractall('Rempah')

# %%
# Path to the dataset folder on Google Drive
DATASET_PATH = '/content/Rempah/Rempah'

# Set your image size and batch size
IMG_SIZE = [128, 128]
BATCH_SIZE = 16

# Create a Path object for the dataset
data_dir = pathlib.Path(DATASET_PATH)

# Use image_dataset_from_directory to load the dataset
dataset = image_dataset_from_directory(data_dir,
                                        shuffle=True,
                                        batch_size=BATCH_SIZE,
                                        image_size=IMG_SIZE,
                                        interpolation='nearest',
                                        label_mode='categorical')

# Split the dataset into training and validation sets
class_names = dataset.class_names
class_number = len(class_names)
nbr_batches = tf.data.experimental.cardinality(dataset)
# Out:
# Found 1028 files belonging to 7 classes.

# %%
# Take 20% for validation
validation_dataset = dataset.take(nbr_batches // 5)
train_dataset = dataset.skip(nbr_batches // 5)

# Visualize some images from the training dataset
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))
        plt.title(class_names[tf.argmax(labels[i])])
        plt.axis('off')

# Data augmentation
augmenter = iaa.Sequential([
    iaa.Sometimes(0.5, iaa.MotionBlur((3, 4)), name='SometimesMotionBlur'),
    iaa.Sometimes(0.5, iaa.GaussianBlur((0.0, 0.75)), name='SometimesGaussianBlur'),
    iaa.GammaContrast((0.7, 1.5)),
    iaa.MultiplySaturation((0.9, 1.5)),
    iaa.MultiplyAndAddToBrightness(),
    iaa.Fliplr(p=0.5),
    iaa.Affine(scale=(1, 1.3),
              translate_percent={"x": (-0.3, 0.3), "y": (-0.3, 0.3)},
              rotate=(-25, 25))
])

def augmentation_function(images, labels):
    img_dtype = images.dtype
    img_shape = tf.shape(images)
    images = tf.numpy_function(augmenter.augment_images,
                               [images],
                               img_dtype)
    images = tf.reshape(images, shape=img_shape)
    return images, labels

# Apply augmentation to the training dataset
train_dataset = train_dataset.map(augmentation_function, num_parallel_calls=tf.data.AUTOTUNE)

# %%
# Preprocess and prefetch the datasets
def preprocess_dataset(dataset):
    return dataset.map(lambda img, label: (tf.keras.applications.mobilenet_v2.preprocess_input(tf.cast(img, tf.float32)), label),
                       num_parallel_calls=tf.data.AUTOTUNE).prefetch(buffer_size=tf.data.AUTOTUNE)

train_dataset = preprocess_dataset(train_dataset)  # Preprocess and prefetch the training dataset
validation_dataset = preprocess_dataset(validation_dataset)  # Preprocess and prefetch the validation dataset

# Load MobileNetV2 as the base model
IMG_SHAPE = (*IMG_SIZE, 3)
base_model = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = True  # Allow fine-tuning of the base model

# Fine-tune only the later layers
fine_tune_at = 100
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False  # Freeze layers up to the specified index

# Build the model with increased dropout, batch normalization, and L2 regularization
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(class_number, activation='softmax', kernel_regularizer=tf.keras.regularizers.l2(0.001))
])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_128 (Func  (None, 4, 4, 1280)        2257984
#  tional)
#
#  global_average_pooling2d (  (None, 1280)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  batch_normalization (Batch  (None, 1280)              5120
#  Normalization)
#
#  dense (Dense)               (None, 256)               327936
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 2593863 (9.89 MB)
# Trainable params: 2194247 (8.37 MB)
# Non-trainable params: 399616 (1.52 MB)
# _________________________________________________________________

# %%
# Use a learning rate schedule
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.0001,  # Initial learning rate
    decay_steps=10000,  # Decay steps
    decay_rate=0.9  # Decay rate
)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),  # Compile the model with Adam optimizer and learning rate schedule
              loss=tf.keras.losses.CategoricalCrossentropy(),  # Categorical crossentropy loss for multi-class classification
              metrics=['accuracy'])  # Monitoring accuracy during training

# Define EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitoring validation loss
    patience=20,  # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
)

# Define custom callback to stop training when both training and validation accuracies exceed 0.95
class CustomCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        if logs['accuracy'] > 0.88 and logs['val_accuracy'] > 0.90:
            self.model.stop_training = True  # Stop training if both training and validation accuracies exceed 0.95

# Define the custom callback
custom_callback = CustomCallback()

# Train the model with the custom callback and early stopping
history = model.fit(train_dataset, epochs=150, validation_data=validation_dataset, callbacks=[custom_callback, early_stopping])
# Out:
# Epoch 1/150
# 52/52 [==============================] - 24s 129ms/step - loss: 2.9354 - accuracy: 0.1829 - val_loss: 2.2432 - val_accuracy: 0.2692
# Epoch 2/150
# 52/52 [==============================] - 8s 145ms/step - loss: 2.7554 - accuracy: 0.2354 - val_loss: 2.0741 - val_accuracy: 0.3798
# Epoch 3/150
# 52/52 [==============================] - 7s 116ms/step - loss: 2.5903 - accuracy: 0.2524 - val_loss: 1.9258 - val_accuracy: 0.4615
# Epoch 4/150
# 52/52 [==============================] - 6s 100ms/step - loss: 2.4916 - accuracy: 0.3110 - val_loss: 1.7618 - val_accuracy: 0.5673
# Epoch 5/150
# 52/52 [==============================] - 7s 124ms/step - loss: 2.3047 - accuracy: 0.3329 - val_loss: 1.6525 - val_accuracy: 0.5913
# Epoch 6/150
# 52/52 [==============================] - 6s 102ms/step - loss: 2.2280 - accuracy: 0.3622 - val_loss: 1.6242 - val_accuracy: 0.6010
# Epoch 7/150
# 52/52 [==============================] - 6s 101ms/step - loss: 2.1514 - accuracy: 0.4110 - val_loss: 1.5414 - val_accuracy: 0.5625
# Epoch 8/150
# 52/52 [==============================] - 7s 123ms/step - loss: 2.1519 - accuracy: 0.4049 - val_loss: 1.5346 - val_accuracy: 0.6058
# Epoch 9/150
# 52/52 [==============================] - 6s 103ms/step - loss: 1.9983 - accuracy: 0.4451 - val_loss: 1.4634 - val_accuracy: 0.6058
# Epoch 10/150
# 52/52 [==============================] - 6s 101ms/step - loss: 2.0189 - accuracy: 0.4561 - val_loss: 1.4502 - val_accuracy: 0.6202
# Epoch 11/150
# 52/52 [==============================] - 7s 115ms/step - loss: 1.8852 - accuracy: 0.5049 - val_loss: 1.3668 - val_accuracy: 0.6779
# Epoch 12/150
# 52/52 [==============================] - 6s 102ms/step - loss: 1.8418 - accuracy: 0.5195 - val_loss: 1.2921 - val_accuracy: 0.7019
# Epoch 13/150
# 52/52 [==============================] - 6s 103ms/step - loss: 1.8410 - accuracy: 0.5000 - val_loss: 1.2848 - val_accuracy: 0.7212
# Epoch 14/150
# 52/52 [==============================] - 6s 99ms/step - loss: 1.7354 - accuracy: 0.5585 - val_loss: 1.3015 - val_accuracy: 0.7212
# Epoch 15/150
# 52/52 [==============================] - 6s 100ms/step - loss: 1.7538 - accuracy: 0.5280 - val_loss: 1.2527 - val_accuracy: 0.7260
# Epoch 16/150
# 52/52 [==============================] - 7s 125ms/step - loss: 1.7412 - accuracy: 0.5390 - val_loss: 1.2307 - val_accuracy: 0.7308
# Epoch 17/150
# 52/52 [==============================] - 6s 101ms/step - loss: 1.6777 - accuracy: 0.5683 - val_loss: 1.2090 - val_accuracy: 0.7308
# Epoch 18/150
# 52/52 [==============================] - 7s 123ms/step - loss: 1.6537 - accuracy: 0.5622 - val_loss: 1.1477 - val_accuracy: 0.7692
# Epoch 19/150
# 52/52 [==============================] - 6s 113ms/step - loss: 1.6529 - accuracy: 0.5756 - val_loss: 1.1359 - val_accuracy: 0.7212
# Epoch 20/150
# 52/52 [==============================] - 7s 126ms/step - loss: 1.6582 - accuracy: 0.5585 - val_loss: 1.0954 - val_accuracy: 0.7452
# Epoch 21/150
# 52/52 [==============================] - 6s 102ms/step - loss: 1.5462 - accuracy: 0.6024 - val_loss: 1.1428 - val_accuracy: 0.7596
# Epoch 22/150
# 52/52 [==============================] - 7s 122ms/step - loss: 1.5217 - accuracy: 0.6366 - val_loss: 1.1257 - val_accuracy: 0.7644
# Epoch 23/150
# 52/52 [==============================] - 7s 117ms/step - loss: 1.5892 - accuracy: 0.5963 - val_loss: 1.0991 - val_accuracy: 0.7788
# Epoch 24/150
# 52/52 [==============================] - 6s 101ms/step - loss: 1.4836 - accuracy: 0.6500 - val_loss: 1.1422 - val_accuracy: 0.7644
# Epoch 25/150
# 52/52 [==============================] - 7s 123ms/step - loss: 1.4379 - accuracy: 0.6622 - val_loss: 1.1140 - val_accuracy: 0.7644
# Epoch 26/150
# 52/52 [==============================] - 7s 115ms/step - loss: 1.4873 - accuracy: 0.6646 - val_loss: 0.9985 - val_accuracy: 0.8077
# Epoch 27/150
# 52/52 [==============================] - 6s 98ms/step - loss: 1.3814 - accuracy: 0.6512 - val_loss: 1.1237 - val_accuracy: 0.8029
# Epoch 28/150
# 52/52 [==============================] - 6s 97ms/step - loss: 1.4045 - accuracy: 0.6622 - val_loss: 1.0926 - val_accuracy: 0.7981
# Epoch 29/150
# 52/52 [==============================] - 7s 119ms/step - loss: 1.4628 - accuracy: 0.6573 - val_loss: 1.0070 - val_accuracy: 0.8125
# Epoch 30/150
# 52/52 [==============================] - 6s 99ms/step - loss: 1.3947 - accuracy: 0.6646 - val_loss: 1.0244 - val_accuracy: 0.8077
# Epoch 31/150
# 52/52 [==============================] - 7s 114ms/step - loss: 1.3876 - accuracy: 0.6585 - val_loss: 1.0043 - val_accuracy: 0.8173
# Epoch 32/150
# 52/52 [==============================] - 6s 98ms/step - loss: 1.3078 - accuracy: 0.6890 - val_loss: 1.0377 - val_accuracy: 0.7692
# Epoch 33/150
# 52/52 [==============================] - 7s 113ms/step - loss: 1.3132 - accuracy: 0.7024 - val_loss: 1.0355 - val_accuracy: 0.7644
# Epoch 34/150
# 52/52 [==============================] - 7s 127ms/step - loss: 1.3423 - accuracy: 0.6976 - val_loss: 0.9469 - val_accuracy: 0.8269
# Epoch 35/150
# 52/52 [==============================] - 6s 98ms/step - loss: 1.2799 - accuracy: 0.7024 - val_loss: 1.0054 - val_accuracy: 0.8173
# Epoch 36/150
# 52/52 [==============================] - 7s 122ms/step - loss: 1.3334 - accuracy: 0.6805 - val_loss: 0.9744 - val_accuracy: 0.8317
# Epoch 37/150
# 52/52 [==============================] - 6s 101ms/step - loss: 1.3109 - accuracy: 0.7159 - val_loss: 0.9374 - val_accuracy: 0.8269
# Epoch 38/150
# 52/52 [==============================] - 6s 101ms/step - loss: 1.3774 - accuracy: 0.6951 - val_loss: 0.9178 - val_accuracy: 0.8413
# Epoch 39/150
# 52/52 [==============================] - 7s 121ms/step - loss: 1.2553 - accuracy: 0.7329 - val_loss: 0.9337 - val_accuracy: 0.8173
# Epoch 40/150
# 52/52 [==============================] - 6s 96ms/step - loss: 1.2856 - accuracy: 0.7171 - val_loss: 0.9278 - val_accuracy: 0.8365
# Epoch 41/150
# 52/52 [==============================] - 7s 116ms/step - loss: 1.2211 - accuracy: 0.7134 - val_loss: 0.9886 - val_accuracy: 0.8269
# Epoch 42/150
# 52/52 [==============================] - 6s 99ms/step - loss: 1.2281 - accuracy: 0.7183 - val_loss: 0.9435 - val_accuracy: 0.8413
# Epoch 43/150
# 52/52 [==============================] - 6s 102ms/step - loss: 1.1619 - accuracy: 0.7524 - val_loss: 0.9237 - val_accuracy: 0.8510
# Epoch 44/150
# 52/52 [==============================] - 6s 103ms/step - loss: 1.1958 - accuracy: 0.7341 - val_loss: 0.9150 - val_accuracy: 0.8606
# Epoch 45/150
# 52/52 [==============================] - 7s 120ms/step - loss: 1.2209 - accuracy: 0.7159 - val_loss: 0.9102 - val_accuracy: 0.8462
# Epoch 46/150
# 52/52 [==============================] - 6s 98ms/step - loss: 1.1283 - accuracy: 0.7732 - val_loss: 0.9952 - val_accuracy: 0.8029
# Epoch 47/150
# 52/52 [==============================] - 6s 98ms/step - loss: 1.1793 - accuracy: 0.7463 - val_loss: 0.9147 - val_accuracy: 0.8606
# Epoch 48/150
# 52/52 [==============================] - 6s 98ms/step - loss: 1.1918 - accuracy: 0.7341 - val_loss: 0.8435 - val_accuracy: 0.8654
# Epoch 49/150
# 52/52 [==============================] - 7s 120ms/step - loss: 1.1832 - accuracy: 0.7402 - val_loss: 0.9223 - val_accuracy: 0.8317
# Epoch 50/150
# 52/52 [==============================] - 6s 99ms/step - loss: 1.1403 - accuracy: 0.7488 - val_loss: 0.8797 - val_accuracy: 0.8462
# Epoch 51/150
# 52/52 [==============================] - 7s 120ms/step - loss: 1.1116 - accuracy: 0.7732 - val_loss: 0.9019 - val_accuracy: 0.8558
# Epoch 52/150
# 52/52 [==============================] - 6s 97ms/step - loss: 1.0645 - accuracy: 0.7659 - val_loss: 0.8626 - val_accuracy: 0.8606
# Epoch 53/150
# 52/52 [==============================] - 7s 124ms/step - loss: 1.1661 - accuracy: 0.7451 - val_loss: 0.7837 - val_accuracy: 0.8750
# Epoch 54/150
# 52/52 [==============================] - 6s 99ms/step - loss: 1.1155 - accuracy: 0.7671 - val_loss: 0.8493 - val_accuracy: 0.8798
# Epoch 55/150
# 52/52 [==============================] - 8s 142ms/step - loss: 1.0558 - accuracy: 0.7805 - val_loss: 0.8464 - val_accuracy: 0.8510
# Epoch 56/150
# 52/52 [==============================] - 7s 106ms/step - loss: 1.0773 - accuracy: 0.7659 - val_loss: 0.9100 - val_accuracy: 0.8462
# Epoch 57/150
# 52/52 [==============================] - 7s 116ms/step - loss: 0.9938 - accuracy: 0.8329 - val_loss: 0.8684 - val_accuracy: 0.8606
# Epoch 58/150
# 52/52 [==============================] - 6s 100ms/step - loss: 1.0647 - accuracy: 0.7915 - val_loss: 0.7945 - val_accuracy: 0.8798
# Epoch 59/150
# 52/52 [==============================] - 7s 122ms/step - loss: 1.0696 - accuracy: 0.7780 - val_loss: 0.9184 - val_accuracy: 0.8558
# Epoch 60/150
# 52/52 [==============================] - 7s 116ms/step - loss: 1.0239 - accuracy: 0.7963 - val_loss: 0.8216 - val_accuracy: 0.8702
# Epoch 61/150
# 52/52 [==============================] - 6s 102ms/step - loss: 1.0537 - accuracy: 0.7683 - val_loss: 0.7972 - val_accuracy: 0.8702
# Epoch 62/150
# 52/52 [==============================] - 7s 119ms/step - loss: 1.0064 - accuracy: 0.8037 - val_loss: 0.8070 - val_accuracy: 0.8798
# Epoch 63/150
# 52/52 [==============================] - 6s 97ms/step - loss: 0.9558 - accuracy: 0.8146 - val_loss: 0.8859 - val_accuracy: 0.8558
# Epoch 64/150
# 52/52 [==============================] - 7s 121ms/step - loss: 1.0035 - accuracy: 0.8159 - val_loss: 0.8473 - val_accuracy: 0.8413
# Epoch 65/150
# 52/52 [==============================] - 6s 99ms/step - loss: 1.0184 - accuracy: 0.8049 - val_loss: 0.7385 - val_accuracy: 0.8702
# Epoch 66/150
# 52/52 [==============================] - 7s 121ms/step - loss: 0.9824 - accuracy: 0.7976 - val_loss: 0.8368 - val_accuracy: 0.8510
# Epoch 67/150
# 52/52 [==============================] - 6s 98ms/step - loss: 0.9699 - accuracy: 0.8207 - val_loss: 0.8601 - val_accuracy: 0.8510
# Epoch 68/150
# 52/52 [==============================] - 6s 96ms/step - loss: 0.9432 - accuracy: 0.8183 - val_loss: 0.7734 - val_accuracy: 0.8702
# Epoch 69/150
# 52/52 [==============================] - 7s 107ms/step - loss: 0.9275 - accuracy: 0.8268 - val_loss: 0.8293 - val_accuracy: 0.8654
# Epoch 70/150
# 52/52 [==============================] - 7s 120ms/step - loss: 0.8991 - accuracy: 0.8317 - val_loss: 0.9102 - val_accuracy: 0.8365
# Epoch 71/150
# 52/52 [==============================] - 6s 98ms/step - loss: 0.9632 - accuracy: 0.8159 - val_loss: 0.8286 - val_accuracy: 0.8702
# Epoch 72/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.9961 - accuracy: 0.7927 - val_loss: 0.8009 - val_accuracy: 0.8654
# Epoch 73/150
# 52/52 [==============================] - 9s 153ms/step - loss: 0.9576 - accuracy: 0.8012 - val_loss: 0.8026 - val_accuracy: 0.8846
# Epoch 74/150
# 52/52 [==============================] - 7s 124ms/step - loss: 0.9088 - accuracy: 0.8402 - val_loss: 0.8155 - val_accuracy: 0.8606
# Epoch 75/150
# 52/52 [==============================] - 6s 112ms/step - loss: 0.8826 - accuracy: 0.8329 - val_loss: 0.8247 - val_accuracy: 0.8462
# Epoch 76/150
# 52/52 [==============================] - 7s 128ms/step - loss: 0.9119 - accuracy: 0.8293 - val_loss: 0.8250 - val_accuracy: 0.8558
# Epoch 77/150
# 52/52 [==============================] - 6s 99ms/step - loss: 0.9063 - accuracy: 0.8280 - val_loss: 0.8408 - val_accuracy: 0.8510
# Epoch 78/150
# 52/52 [==============================] - 7s 119ms/step - loss: 0.8591 - accuracy: 0.8537 - val_loss: 0.8049 - val_accuracy: 0.8750
# Epoch 79/150
# 52/52 [==============================] - 6s 97ms/step - loss: 0.8904 - accuracy: 0.8390 - val_loss: 0.7825 - val_accuracy: 0.9038
# Epoch 80/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.9836 - accuracy: 0.8280 - val_loss: 0.7292 - val_accuracy: 0.8894
# Epoch 81/150
# 52/52 [==============================] - 6s 98ms/step - loss: 0.9081 - accuracy: 0.8329 - val_loss: 0.7569 - val_accuracy: 0.9038
# Epoch 82/150
# 52/52 [==============================] - 7s 115ms/step - loss: 0.8733 - accuracy: 0.8463 - val_loss: 0.7855 - val_accuracy: 0.8750
# Epoch 83/150
# 52/52 [==============================] - 6s 97ms/step - loss: 0.8433 - accuracy: 0.8549 - val_loss: 0.7698 - val_accuracy: 0.8990
# Epoch 84/150
# 52/52 [==============================] - 7s 124ms/step - loss: 0.8292 - accuracy: 0.8634 - val_loss: 0.7193 - val_accuracy: 0.9087
# Epoch 85/150
# 52/52 [==============================] - 7s 114ms/step - loss: 0.8834 - accuracy: 0.8390 - val_loss: 0.7447 - val_accuracy: 0.8894
# Epoch 86/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.8396 - accuracy: 0.8585 - val_loss: 0.6777 - val_accuracy: 0.9231
# Epoch 87/150
# 52/52 [==============================] - 6s 99ms/step - loss: 0.8557 - accuracy: 0.8451 - val_loss: 0.6794 - val_accuracy: 0.9231
# Epoch 88/150
# 52/52 [==============================] - 7s 121ms/step - loss: 0.8281 - accuracy: 0.8463 - val_loss: 0.7380 - val_accuracy: 0.8894
# Epoch 89/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.8768 - accuracy: 0.8439 - val_loss: 0.8265 - val_accuracy: 0.8894
# Epoch 90/150
# 52/52 [==============================] - 6s 99ms/step - loss: 0.7675 - accuracy: 0.8890 - val_loss: 0.8350 - val_accuracy: 0.8750
# Epoch 91/150
# 52/52 [==============================] - 6s 112ms/step - loss: 0.8451 - accuracy: 0.8463 - val_loss: 0.7522 - val_accuracy: 0.8942
# Epoch 92/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.8088 - accuracy: 0.8683 - val_loss: 0.8402 - val_accuracy: 0.8942
# Epoch 93/150
# 52/52 [==============================] - 6s 110ms/step - loss: 0.8089 - accuracy: 0.8720 - val_loss: 0.7034 - val_accuracy: 0.9135
# Epoch 94/150
# 52/52 [==============================] - 6s 97ms/step - loss: 0.8034 - accuracy: 0.8683 - val_loss: 0.9036 - val_accuracy: 0.8462
# Epoch 95/150
# 52/52 [==============================] - 7s 124ms/step - loss: 0.7861 - accuracy: 0.8695 - val_loss: 0.7741 - val_accuracy: 0.8750
# Epoch 96/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.7847 - accuracy: 0.8659 - val_loss: 0.8607 - val_accuracy: 0.8750
# Epoch 97/150
# 52/52 [==============================] - 7s 122ms/step - loss: 0.7985 - accuracy: 0.8646 - val_loss: 0.7357 - val_accuracy: 0.8942
# Epoch 98/150
# 52/52 [==============================] - 7s 115ms/step - loss: 0.8100 - accuracy: 0.8549 - val_loss: 0.7765 - val_accuracy: 0.8894
# Epoch 99/150
# 52/52 [==============================] - 6s 98ms/step - loss: 0.7619 - accuracy: 0.8720 - val_loss: 0.7436 - val_accuracy: 0.8990
# Epoch 100/150
# 52/52 [==============================] - 6s 100ms/step - loss: 0.8157 - accuracy: 0.8573 - val_loss: 0.7101 - val_accuracy: 0.9135
# Epoch 101/150
# 52/52 [==============================] - 7s 118ms/step - loss: 0.7549 - accuracy: 0.8683 - val_loss: 0.7729 - val_accuracy: 0.8942
# Epoch 102/150
# 52/52 [==============================] - 6s 97ms/step - loss: 0.7372 - accuracy: 0.8841 - val_loss: 0.7575 - val_accuracy: 0.8894
# Epoch 103/150
# 52/52 [==============================] - 7s 119ms/step - loss: 0.8165 - accuracy: 0.8573 - val_loss: 0.7631 - val_accuracy: 0.8798
# Epoch 104/150
# 52/52 [==============================] - 6s 98ms/step - loss: 0.7406 - accuracy: 0.8829 - val_loss: 0.8167 - val_accuracy: 0.8654
# Epoch 105/150
# 52/52 [==============================] - 6s 113ms/step - loss: 0.7338 - accuracy: 0.8866 - val_loss: 0.7139 - val_accuracy: 0.9135

# %%
# Plotting model Accuracy and Loss
plt.figure(figsize=(14, 5))

# Subplot for Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Set Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Set Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy')

# Subplot for Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Set Loss')
plt.plot(history.history['val_loss'], label='Validation Set Loss')
plt.legend(loc='upper right')
plt.title('Loss')

# Show the plots
plt.show()

# %%
# Save the trained model in the SavedModel format
saved_model_path = '/content/Raw_Material_model'
model.save(saved_model_path)
# Out:
# WARNING:absl:`mobilenetv2_1.00_128_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_128_input`.
# WARNING:absl:`mobilenetv2_1.00_128_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_128_input`.
# WARNING:absl:`mobilenetv2_1.00_128_input` is not a valid tf.function parameter name. Sanitizing to `mobilenetv2_1_00_128_input`.

# %%
# Convert SavedModel to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
tflite_model = converter.convert()

# Save the TFLite model to a file
tflite_model_path = '/content/Raw_Material_model.tflite'
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

# %%
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Apply default optimization settings during conversion to TensorFlow Lite

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from google.colab import files

# Load TFLite model
model_path = '/content/Raw_Material_model.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Specify class names
class_names = {
    0: "Andaliman",
    1: "Cabe Jawa",
    2: "Cengkeh",
    3: "Kapulaga",
    4: "Kayu Manis",
    5: "Lada",
    6: "Pala",

}

# Upload the image file
uploaded_images = files.upload()

# Get the image file path
image_path = list(uploaded_images.keys())[0]

# Preprocess the input image
img = Image.open(image_path).resize((128, 128))
img_array = np.array(img) / 255.0  # Normalize to [0, 1]
input_data = np.expand_dims(img_array, axis=0).astype(input_details[0]['dtype'])
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output
output_data = interpreter.get_tensor(output_details[0]['index'])

# Post-process the output
predicted_class = np.argmax(output_data[0])
confidence = output_data[0][predicted_class]

# Display the result
plt.imshow(img)
plt.title(f'Predicted Class: {class_names[predicted_class]}, Confidence: {confidence:.4f}')
plt.axis('off')
plt.show()
